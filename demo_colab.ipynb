# %% [markdown]
# # 🧠 Mímir — Living Memory AI Demo
#
# <p align="center">
#   <img src="https://raw.githubusercontent.com/Kronic90/Mimir/main/MimirLogo.png" width="200">
# </p>
#
# **An interactive demo of [Mímir](https://github.com/Kronic90/Mimir) — 21 neuroscience mechanisms giving AI agents a living, decaying, emotionally rich memory.**
#
# | Feature | Description |
# |---|---|
# | 💬 **Chat** | Talk with Qwen3.5-4B backed by full Mímir memory |
# | 🧠 **Memory Viewer** | Browse episodic memories, social impressions, lessons, tasks, chemistry, Yggdrasil graph |
# | 📥 **Import Memories** | Upload .txt/.json files — the LLM reads them and creates structured memories |
# | ⚙️ **Custom Persona** | Set your own system prompt (text or file upload) |
#
# ---
#
# **Requirements:** Google account + Colab T4 GPU runtime (free tier works).
#
# 1. Click **Runtime → Change runtime type → T4 GPU**
# 2. Run all cells below (▶️ or Ctrl+F9)
# 3. Click the Gradio public URL that appears

# %% [markdown]
# ## 1. Install Dependencies
#
# Qwen3.5 requires the latest transformers (installed from source).

# %%
# !pip install -q vividmimir[all] gradio git+https://github.com/huggingface/transformers.git accelerate bitsandbytes torch

# %% [markdown]
# ## 2. Download & Launch Demo
#
# This downloads the Gradio demo from the repo and runs it.
# A **public URL** will appear below — click it to open the UI.

# %%
import urllib.request, os

DEMO_URL = "https://raw.githubusercontent.com/Kronic90/Mimir/main/mimir_gradio_demo.py"
if not os.path.exists("mimir_gradio_demo.py"):
    urllib.request.urlretrieve(DEMO_URL, "mimir_gradio_demo.py")
    print("Downloaded mimir_gradio_demo.py")
else:
    print("Demo already downloaded")

# Force Colab detection (in case env var is missing)
os.environ["COLAB_GPU"] = "1"

# Run the demo
# %run mimir_gradio_demo.py
